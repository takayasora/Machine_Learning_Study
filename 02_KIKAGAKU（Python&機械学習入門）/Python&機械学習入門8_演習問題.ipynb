# %% [markdown]
# https://www.kikagaku.ai/learning/learn/pre-video/exercise/read-dataset/

# %% [markdown]
# # データの読み込み

# %%
import numpy as np
import pandas as pd

# %%
df =pd.read_csv('./reference/housing.csv')

# %%
df.head(3)
# Out:
#         x1    x2    x3  x4     x5     x6    x7      x8  x9  x10   x11     x12  \
# 0  0.00632  18.0  2.31   0  0.538  6.575  65.2  4.0900   1  296  15.3  396.90
# 1  0.02731   0.0  7.07   0  0.469  6.421  78.9  4.9671   2  242  17.8  396.90
# 2  0.02729   0.0  7.07   0  0.469  7.185  61.1  4.9671   2  242  17.8  392.83
#
#     x13     y
# 0  4.98  24.0
# 1  9.14  21.6
# 2  4.03  34.7

# %%
df.shape
# Out:
# (506, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x1      506 non-null    float64
#  1   x2      506 non-null    float64
#  2   x3      506 non-null    float64
#  3   x4      506 non-null    int64
#  4   x5      506 non-null    float64
#  5   x6      506 non-null    float64
#  6   x7      506 non-null    float64
#  7   x8      506 non-null    float64
#  8   x9      506 non-null    int64
#  9   x10     506 non-null    int64
#  10  x11     506 non-null    float64
#  11  x12     506 non-null    float64
#  12  x13     506 non-null    float64
#  13  y       506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
df.describe()
# Out:
#                x1          x2          x3          x4          x5          x6  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#                x7          x8          x9         x10         x11         x12  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %% [markdown]
# # 分布の確認

# %%
import seaborn as sns

# %%
sns.set()

# %%
sns.distplot(df['x1'],bins=10)
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='x1', ylabel='Density'>

# %%
sns.distplot(df['y'],bins=10)
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='y', ylabel='Density'>

# %% [markdown]
# ## 相関係数

# %%
df.corr()
# Out:
#            x1        x2        x3        x4        x5        x6        x7  \
# x1   1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# x2  -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# x3   0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# x4  -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# x5   0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# x6  -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# x7   0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# x8  -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# x9   0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# x10  0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# x11  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# x12 -0.385064  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# # 入力変数と出力変数の切り分け

# %%
df.head(3)
# Out:
#         x1    x2    x3  x4     x5     x6    x7      x8  x9  x10   x11     x12  \
# 0  0.00632  18.0  2.31   0  0.538  6.575  65.2  4.0900   1  296  15.3  396.90
# 1  0.02731   0.0  7.07   0  0.469  6.421  78.9  4.9671   2  242  17.8  396.90
# 2  0.02729   0.0  7.07   0  0.469  7.185  61.1  4.9671   2  242  17.8  392.83
#
#     x13     y
# 0  4.98  24.0
# 1  9.14  21.6
# 2  4.03  34.7

# %%
df.iloc[:,:-1]
# Out:
#           x1    x2     x3  x4     x5     x6    x7      x8  x9  x10   x11  \
# 0    0.00632  18.0   2.31   0  0.538  6.575  65.2  4.0900   1  296  15.3
# 1    0.02731   0.0   7.07   0  0.469  6.421  78.9  4.9671   2  242  17.8
# 2    0.02729   0.0   7.07   0  0.469  7.185  61.1  4.9671   2  242  17.8
# 3    0.03237   0.0   2.18   0  0.458  6.998  45.8  6.0622   3  222  18.7
# 4    0.06905   0.0   2.18   0  0.458  7.147  54.2  6.0622   3  222  18.7
# ..       ...   ...    ...  ..    ...    ...   ...     ...  ..  ...   ...
# 501  0.06263   0.0  11.93   0  0.573  6.593  69.1  2.4786   1  273  21.0
# 502  0.04527   0.0  11.93   0  0.573  6.120  76.7  2.2875   1  273  21.0
# 503  0.06076   0.0  11.93   0  0.573  6.976  91.0  2.1675   1  273  21.0
# 504  0.10959   0.0  11.93   0  0.573  6.794  89.3  2.3889   1  273  21.0
# 505  0.04741   0.0  11.93   0  0.573  6.030  80.8  2.5050   1  273  21.0
#
#         x12   x13
# 0    396.90  4.98
# 1    396.90  9.14
# 2    392.83  4.03
# ...

# %%
df.iloc[:,-1]
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: y, Length: 506, dtype: float64

# %%
df.head(3)
# Out:
#         x1    x2    x3  x4     x5     x6    x7      x8  x9  x10   x11     x12  \
# 0  0.00632  18.0  2.31   0  0.538  6.575  65.2  4.0900   1  296  15.3  396.90
# 1  0.02731   0.0  7.07   0  0.469  6.421  78.9  4.9671   2  242  17.8  396.90
# 2  0.02729   0.0  7.07   0  0.469  7.185  61.1  4.9671   2  242  17.8  392.83
#
#     x13     y
# 0  4.98  24.0
# 1  9.14  21.6
# 2  4.03  34.7

# %%
df.drop("y",axis=1)
# Out:
#           x1    x2     x3  x4     x5     x6    x7      x8  x9  x10   x11  \
# 0    0.00632  18.0   2.31   0  0.538  6.575  65.2  4.0900   1  296  15.3
# 1    0.02731   0.0   7.07   0  0.469  6.421  78.9  4.9671   2  242  17.8
# 2    0.02729   0.0   7.07   0  0.469  7.185  61.1  4.9671   2  242  17.8
# 3    0.03237   0.0   2.18   0  0.458  6.998  45.8  6.0622   3  222  18.7
# 4    0.06905   0.0   2.18   0  0.458  7.147  54.2  6.0622   3  222  18.7
# ..       ...   ...    ...  ..    ...    ...   ...     ...  ..  ...   ...
# 501  0.06263   0.0  11.93   0  0.573  6.593  69.1  2.4786   1  273  21.0
# 502  0.04527   0.0  11.93   0  0.573  6.120  76.7  2.2875   1  273  21.0
# 503  0.06076   0.0  11.93   0  0.573  6.976  91.0  2.1675   1  273  21.0
# 504  0.10959   0.0  11.93   0  0.573  6.794  89.3  2.3889   1  273  21.0
# 505  0.04741   0.0  11.93   0  0.573  6.030  80.8  2.5050   1  273  21.0
#
#         x12   x13
# 0    396.90  4.98
# 1    396.90  9.14
# 2    392.83  4.03
# ...

# %% [markdown]
# # モデルの構築と検証

# %% [markdown]
# x->入力値
# t->目標値

# %%
x = df.drop("y",axis=1)
t = df["y"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x,t)
# Out:
# LinearRegression()

# %%
model.score(x,t)
# Out:
# 0.7406426641094095

# %% [markdown]
# # 実データで演習

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,t,test_size=0.4,random_state=1)

# %%
len(x_train),len(x_test)
# Out:
# (303, 203)

# %%
len(y_train),len(y_test)
# Out:
# (303, 203)

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)
# Out:
# 0.7468316520140625

# %%
model.score(x_test,y_test)
# Out:
# 0.7209056672661771

# %% [markdown]
# # 予測値の計算とモデルの保存・読み込み

# %%
df.head(1)
# Out:
#         x1    x2    x3  x4     x5     x6    x7    x8  x9  x10   x11    x12  \
# 0  0.00632  18.0  2.31   0  0.538  6.575  65.2  4.09   1  296  15.3  396.9
#
#     x13     y
# 0  4.98  24.0

# %%
sample = x.iloc[0,:]

# %%
sample.shape
# Out:
# (13,)

# %%
y_pred = model.predict([sample])
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
y_pred
# Out:
# array([29.42368847])

# %% [markdown]
# ## モデルの保存

# %%
# ライブラリの廃止に伴い、映像と異なるコードを利用しています
import pickle

# %%
import pickle
with open('./reference/model.pkl', 'wb') as f:
    pickle.dump(model, f)

# %%
with open('./reference/model.pkl', 'rb') as f:
    model_new = pickle.load(f)

# %%
model_new.predict([sample])
# Out:
# C:\Users\Owner\AppData\Roaming\Python\Python310\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([29.42368847])

# %% [markdown]
# # パラメータの確認

# %%
model.coef_
# Out:
# array([-8.95714048e-02,  6.73132853e-02,  5.04649248e-02,  2.18579583e+00,
#        -1.72053975e+01,  3.63606995e+00,  2.05579939e-03, -1.36602886e+00,
#         2.89576718e-01, -1.22700072e-02, -8.34881849e-01,  9.40360790e-03,
#        -5.04008320e-01])

# %%
np.set_printoptions(precision=3)

# %%
model.coef_
# Out:
# array([-8.957e-02,  6.731e-02,  5.046e-02,  2.186e+00, -1.721e+01,
#         3.636e+00,  2.056e-03, -1.366e+00,  2.896e-01, -1.227e-02,
#        -8.349e-01,  9.404e-03, -5.040e-01])

# %%
np.set_printoptions(precision=3,suppress=True)

# %%
model.coef_
# Out:
# array([ -0.09 ,   0.067,   0.05 ,   2.186, -17.205,   3.636,   0.002,
#         -1.366,   0.29 ,  -0.012,  -0.835,   0.009,  -0.504])

# %%
df.head(3)
# Out:
#         x1    x2    x3  x4     x5     x6    x7      x8  x9  x10   x11     x12  \
# 0  0.00632  18.0  2.31   0  0.538  6.575  65.2  4.0900   1  296  15.3  396.90
# 1  0.02731   0.0  7.07   0  0.469  6.421  78.9  4.9671   2  242  17.8  396.90
# 2  0.02729   0.0  7.07   0  0.469  7.185  61.1  4.9671   2  242  17.8  392.83
#
#     x13     y
# 0  4.98  24.0
# 1  9.14  21.6
# 2  4.03  34.7

# %% [markdown]
# ### 重みを見るだけではどの変数が影響を与えているかわからない
# ### 重みが大きくても、x1やx2のもともとの値が小さい大きいを考慮していないので、判断がしずらい
